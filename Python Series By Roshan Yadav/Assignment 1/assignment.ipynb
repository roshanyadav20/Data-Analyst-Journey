# %% [markdown]
# Assignment 1

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("You're a goodman")
# Out:
# You're a goodman

# %%
print("You are a 'good' person")
# Out:
# You are a 'good' person

# %%
print('''You're a "good" person''')
# Out:
# You're a "good" person

# %%
# Q1: Write python program that prints the following text exactly as it appears:
#Python is fun.
#"Quotes" and 'single quotes' can be trickey.

#1st approach
print("Python is fun.")
print('''"Quotes" and 'single quotes' can be trickey.''')
print("\"Quotes\" and 'single quotes' can be trickey.")
# Out:
# Python is fun.
# "Quotes" and 'single quotes' can be trickey.
# "Quotes" and 'single quotes' can be trickey.

# %%
#2nd Approch
print("Python is fun.\n\"Quotes\" and 'single quotes' can be trickey.")
# Out:
# Python is fun.
# "Quotes" and 'single quotes' can be trickey.

# %% [markdown]
# Q2: For a business create 3 variables to store-name, age, and city. Then print a sentence that uses these variables.

# %%
# 1st Way 
name = "Roshan"
age = 22
city = "Sultanpur"
print("My name is", name, "from", city, "& I'm", age )
# Out:
# My name is Roshan from Sultanpur & I'm 22

# %%
# 2nd Way
# f string

print(f"My name is {name} from {city} & I'm {age}")
# Out:
# My name is Roshan from Sultanpur & I'm 22
